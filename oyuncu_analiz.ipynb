# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fBERkblbV6p4KqyYXXGj")
project = rf.workspace("newworkspace-tmqsj").project("player-detection-gklrl-wmudy")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 119.9 MB/s  0:00:00m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 47.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 104.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 51.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 82.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 154.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 127.1 MB/s  0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0━━━━━━━━━━━━━━━━━━━━━━  4/15 [Pillow]
#   Attempting uninstall: idna0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━  5/15 [opencv-python-headless]
#     Found existing installation: idna 3.10━━━━━━━━━━━━━━━━━━━━  5/15 [opencv-python-headless]
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO
import os

print("Ultralytics kütüphanesi başarıyla yüklendi.")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 161.9 MB/s  0:00:00m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.4/802.4 kB 39.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 MB 111.8 MB/s  0:00:00m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 161.7 MB/s  0:00:00m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [ultralytics] [ultralytics]n]-32]
# ...
# WARNING ⚠️ user config directory '/root/.config/Ultralytics' is not writable, using '/tmp/Ultralytics'. Set YOLO_CONFIG_DIR to override.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/tmp/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics kütüphanesi başarıyla yüklendi.

# %%
model_name = 'yolov8s.pt'
model = YOLO(model_name) 

data_yaml_path = '/workspace/Player-Detection-1/data.yaml' 

num_epochs = 50
image_size = 640
output_project_name = 'futbol_tespit_projesi'
run_name = 'yolov8s_v1'

print(f"Eğitim {num_epochs} çağ (epoch) boyunca başlayacak...")

results = model.train(
    data=data_yaml_path,        # Veri setinizin YAML dosyası
    epochs=num_epochs,          # Eğitim çağ sayısı
    imgsz=image_size,           # Görüntü boyutu
    batch=-1,                   # Otomatik en iyi toplu iş boyutunu seç (-1)
    project=output_project_name,# Çıktı klasörü (ana klasör)
    name=run_name,              # Eğitimin adı (çıktı klasörünün içindeki klasör)
    workers=8,                  # Veri yükleme işçisi sayısı (sistem çekirdeğinize göre ayarlayın)
    patience=20,                # Performans artmazsa eğitimi durdurmak için sabır süresi
)

print("\n--- Eğitim Tamamlandı ---")
print(f"Sonuçlar şurada kaydedildi: {output_project_name}/{run_name}")
# Out:
# ...
# Eğitim 50 çağ (epoch) boyunca başlayacak...
# Ultralytics 8.3.237 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32120MiB)
# ...
